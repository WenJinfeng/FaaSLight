# %%
import os
import json
import sys
sys.setrecursionlimit(5000000)

# %%
input_package  = "testAPP"

# %%
assetsDir = {
    #Directories to ignore
    "ignorDir" : ["__pycache__", "tests", ".serverless", "pip", "pkg_resources", "setuptools", "wheel", "_distutils_hack"], 
    # Specific directories to ignore
    "ignorSpeDir": [".dist-info"],  
    #Files to ignore
    "ignorFile": [".pyc", ".pyi", ".pth", ".virtualenv","_virtualenv.py",".md"],
}

# %% [markdown]
# step 1

# %%
import removefile
removefile.delFiles(input_package, assetsDir)

entry_py = ["main"]
input_entry_point =[]
for i in entry_py:
    input_entry_point.append("{}/{}.py".format(input_package, i))
# input_entry_point = ["{}/{}.py".format(input_package, entry_py)]

output_file = "{}/output.json".format(input_package)


print(f"dirname : {input_package}")
print(f"path:    {input_entry_point}")
print(f"moshuoutput:  {output_file}")
# Out:
# dirname : testAPP
# path:    ['testAPP/main.py']
# moshuoutput:  testAPP/output.json

# %% [markdown]
# step 2

# %%
import os
os.system("python pycg/__main__.py --package {} {} -o {}".format(input_package, " ".join(input_entry_point), output_file))
# Out:
# preprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/main.py
# preprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/__init__.py
# preprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/_version.py
# preprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/api.py
# preprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/arrow.py
# preprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/formatter.py
# preprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/locales.py
# preprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/custom_funtemplate.py
# preprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/lazy_import/__init__.py
# preprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/six.py
# preprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/constants.py
# preprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/parser.py
# preprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/util.py
# preprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/factory.py
# postprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/main.py
# postprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/__init__.py
# postprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/_version.py
# postprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/api.py
# postprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/constants.py
# postprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/arrow.py
# postprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/util.py
# postprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/custom_funtemplate.py
# postprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/lazy_import/__init__.py
# postprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/six.py
# postprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/locales.py
# postprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/formatter.py
# postprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/parser.py
# postprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/factory.py
# postprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/main.py
# postprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/__init__.py
# postprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/_version.py
# postprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/api.py
# postprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/constants.py
# postprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/arrow.py
# postprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/util.py
# postprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/custom_funtemplate.py
# postprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/lazy_import/__init__.py
# postprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/six.py
# postprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/locales.py
# postprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/formatter.py
# postprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/parser.py
# postprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/factory.py
# postprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/main.py
# postprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/__init__.py
# postprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/_version.py
# postprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/api.py
# postprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/constants.py
# postprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/arrow.py
# postprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/util.py
# postprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/custom_funtemplate.py
# postprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/lazy_import/__init__.py
# postprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/six.py
# postprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/locales.py
# postprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/formatter.py
# postprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/parser.py
# postprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/factory.py
# callgraphprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/main.py
# into cgprocessing analyze
# callgraphprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/__init__.py
# into cgprocessing analyze
# callgraphprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/_version.py
# into cgprocessing analyze
# callgraphprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/api.py
# into cgprocessing analyze
# callgraphprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/constants.py
# into cgprocessing analyze
# callgraphprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/arrow.py
# into cgprocessing analyze
# callgraphprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/util.py
# into cgprocessing analyze
# callgraphprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/custom_funtemplate.py
# into cgprocessing analyze
# callgraphprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/lazy_import/__init__.py
# into cgprocessing analyze
# callgraphprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/six.py
# into cgprocessing analyze
# callgraphprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/locales.py
# into cgprocessing analyze
# callgraphprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/formatter.py
# into cgprocessing analyze
# callgraphprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/parser.py
# into cgprocessing analyze
# callgraphprocessor init----/home/wsys/ServerlessApp/ServerlessApp-main20220225/testAPP/arrow/factory.py
# into cgprocessing analyze
# 0

# %%
dir_name = input_package.split('/')[-1]

# Process handler functions
# OK First need to get the seed function collection
ymlFile= "{}/serverless.yml".format(input_package)
seedfun_list = []
if os.path.exists(ymlFile):
    import utiltool
    seedfun_list = utiltool.foryml(ymlFile)
    
print(seedfun_list)
# Out:
# ['main.lambda_handler', 'main']

# %% [markdown]
# step 3

# %%
Identify_name = "reqs"

moshu_file = "moshu_functions/{}.txt".format(Identify_name)
 
os.system("python find_moshu_origin.py --dirname {} --path {} --moshuoutput {}".format(dir_name, input_package, moshu_file))
# Out:
# testAPP/main.py
# testAPP/six.py
# six._GeneratorWrapper.__iter__
# six.X.__len__
# testAPP/custom_funtemplate.py
# testAPP/lazy_import/__init__.py
# testAPP/arrow/_version.py
# testAPP/arrow/constants.py
# testAPP/arrow/parser.py
# testAPP/arrow/util.py
# testAPP/arrow/factory.py
# testAPP/arrow/locales.py
# testAPP/arrow/api.py
# testAPP/arrow/formatter.py
# testAPP/arrow/__init__.py
# testAPP/arrow/arrow.py
# ['six._GeneratorWrapper.__iter__', 'six.X.__len__']
# 0

# %% [markdown]
# step 4

# %%
# user_handler = ["handler.handler"]

re_FunRel = "{}/output-re.json".format(input_package)
# re_FunRel ="/disk/wjf/source36/funcRelation-new.json" 


if len(seedfun_list)<=0:
    user_handler = []
    if os.path.exists("entry_point.txt"):
        for line in open("entry_point.txt"):
            line = line.strip('\n')
            if len(line)>0:
                user_handler.append(line)
    if len(user_handler)>0:
        seedfun_list.extend(user_handler)
        for i in user_handler:
            temp = i.split(".")
            if len(temp)>1:
                new_seed = ".".join(temp[:-1])
                    # print(new_seed)
                seedfun_list.append(new_seed)




if not os.path.exists(output_file):
    os.mknod(output_file)
    intial_key={}
    for seed_i in seedfun_list:
        intial_key[seed_i] = []
        # temp = seed_i.split(".")
        # if len(temp)>1:
        #     new_seed = ".".join(temp[:-1])
        #     print(new_seed)
        #     intial_key[new_seed] = []

    with open(output_file, "w", encoding='utf-8') as f:
        f.write(json.dumps(intial_key))
        print("output.json build")
    f.close()



import staticAdd
staticAdd.add_info(input_package, output_file, input_entry_point, moshu_file, re_FunRel)
# Out:
# Processing--------testAPP/main.py
# start 0
# key value
# ttttttttttt
# add key
# start 2 loop
# start 3 loop

# %% [markdown]
# step 5

# %%
used_fun_result_output = "used_func_result/used_func_{}.txt".format(Identify_name)
import dynamicprocess

print(re_FunRel)
dynamicprocess.getDynamicContent_new(seedfun_list, input_package, re_FunRel, input_entry_point, used_fun_result_output)
# Out:
# testAPP/output-re.json
# processing---------------testAPP/main.py
# ====================================================
# ['main', 'main.lambda_handler']
# 1----cunzai
# 1----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# ['arrow.formatter', 'arrow.arrow', 'arrow.__init__', 'arrow.util', 'main', 'arrow.parser', 'arrow.api', 'arrow.constants', 'arrow.factory', 'arrow.locales']
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# ['.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.toordinal', 'arrow.parser.DateTimeParser.parse', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow._get_frames', 'arrow.locales.TimeFrameLiteral', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow', 'arrow.arrow.Arrow', 'arrow.arrow.Arrow.fromdatetime', 'typing.Iterable', 'datetime.datetime.strptime', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.formatter.FORMAT_W3C', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.formatter.DateTimeFormatter.format', 'arrow.arrow.Arrow.__init__', 'time.struct_time', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.fold', 'arrow.formatter.DateTimeFormatter.__init__', 'typing.ClassVar', 'typing.Pattern', 'arrow.parser.TzinfoParser.parse', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.format', 'typing_extensions.Literal', 'arrow.parser.DateTimeParser._parse_multiformat', 're.split', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.fromordinal', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.weekday', '<builtin>.TypeError', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.utcfromtimestamp', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.dehumanize', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.locales.Locale.month_name', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.strftime', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.formatter.DateTimeFormatter._format_token', 'arrow.__init__.__version__', 'arrow.arrow.Arrow.fromdate', 'arrow.parser.DateTimeParser.parse_iso', '<builtin>.getattr', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.main.lambda_handler', 're.IGNORECASE', 'arrow.formatter.DateTimeFormatter', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.__hash__', 'typing.Match', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.formatter.FORMAT_RSS', 'dateutil.tz.tzoffset', 'dateutil.tz.tzlocal', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.__format__', 'datetime.tzinfo', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.isoweekday', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.parser.DateTimeParser._generate_pattern_re', 'datetime.datetime.max.timestamp', 'arrow.util', 'datetime.datetime.max', 'arrow.api', 'typing.Tuple', 'calendar.timegm', 'datetime.date', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.parser.TzinfoParser.parse', 'arrow.parser.DateTimeParser._parse_token', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.interval', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.__radd__', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.parser._Parts', 'typing.Sequence', 'typing.SupportsInt', 're.error', 'arrow.parser.DateTimeParser.__init__', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.formatter.FORMAT_COOKIE', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.span', 'typing.Optional', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.api.utcnow', 'decimal.Decimal', 'arrow.parser.DateTimeParser', 'arrow.now', 'arrow.factory.ArrowFactory.now', 'arrow.get', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.parser.ParserMatchError', 'arrow.arrow.Arrow.utcfromtimestamp', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.strptime', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.int_timestamp', 'main', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow ...
# end====================================================
# find possible note
# start
# start=====1===========
# ['', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.toordinal', 'arrow.parser.DateTimeParser.parse', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow._get_frames', 'arrow.locales.TimeFrameLiteral', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow', 'arrow.arrow.Arrow', 'arrow.arrow.Arrow.fromdatetime', 'typing.Iterable', 'datetime.datetime.strptime', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.formatter.FORMAT_W3C', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.formatter.DateTimeFormatter.format', 'arrow.arrow.Arrow.__init__', 'time.struct_time', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.fold', 'arrow.formatter.DateTimeFormatter.__init__', 'typing.ClassVar', 'typing.Pattern', 'arrow.parser.TzinfoParser.parse', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.format', 'typing_extensions.Literal', 'arrow.parser.DateTimeParser._parse_multiformat', 're.split', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.fromordinal', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.weekday', '<builtin>.TypeError', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.utcfromtimestamp', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.dehumanize', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.locales.Locale.month_name', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.strftime', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.formatter.DateTimeFormatter._format_token', 'arrow.__init__.__version__', 'arrow.arrow.Arrow.fromdate', 'arrow.parser.DateTimeParser.parse_iso', '<builtin>.getattr', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.main.lambda_handler', 're.IGNORECASE', 'arrow.formatter.DateTimeFormatter', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.__hash__', 'typing.Match', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.formatter.FORMAT_RSS', 'dateutil.tz.tzoffset', 'dateutil.tz.tzlocal', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.__format__', 'datetime.tzinfo', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.isoweekday', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.parser.DateTimeParser._generate_pattern_re', 'datetime.datetime.max.timestamp', 'arrow.util', 'datetime.datetime.max', 'arrow.api', 'typing.Tuple', 'datetime.date', 'calendar.timegm', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.parser.TzinfoParser.parse', 'arrow.parser.DateTimeParser._parse_token', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.interval', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.__radd__', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.parser._Parts', 'typing.Sequence', 'typing.SupportsInt', 're.error', 'arrow.parser.DateTimeParser.__init__', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.formatter.FORMAT_COOKIE', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.span', 'typing.Optional', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.api.utcnow', 'decimal.Decimal', 'arrow.parser.DateTimeParser', 'arrow.now', 'arrow.factory.ArrowFactory.now', 'arrow.get', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.parser.ParserMatchError', 'arrow.arrow.Arrow.utcfromtimestamp', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.strptime', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.int_timestamp', 'main', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.A ...
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# ['arrow.formatter', 'arrow.arrow', 'arrow.__init__', 'arrow.util', 'main', 'arrow.parser', 'arrow.api', 'arrow.constants', 'arrow.factory', 'arrow.locales']
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# add result
# done！

# %% [markdown]
# step 6

# %%
# OK Step 6, determine what package names exist in the pure function coverage set, generate new magic function files with final ending
# Need to determine whether to add magic functions, only use magic functions if related packages are used

# Determine packages contained in the first two names of the string (separated by .)
used_package_name = "used_func_result/used_package_{}.txt".format(Identify_name)

# %%
import isContainPackage
isContainPackage.getPackgaeName(used_fun_result_output, input_package, used_package_name)
# Out:
# ['']
# 2
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', '_version', '__version__']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'api', 'get']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'api', 'now']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'api', 'utcnow']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'Arrow']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'Arrow', '__add__']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'Arrow', '__format__']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'Arrow', '__getattr__']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'Arrow', '__hash__']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'Arrow', '__radd__']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'Arrow', '__str__']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'Arrow', '_get_datetime']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'Arrow', '_get_frames']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'Arrow', '_get_iteration_params']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'Arrow', '_get_tzinfo']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'Arrow', '_is_last_day_of_month']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'Arrow', 'ambiguous']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'Arrow', 'astimezone']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'Arrow', 'date']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'Arrow', 'datetime']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'Arrow', 'dehumanize']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'Arrow', 'float_timestamp']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'Arrow', 'fold']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'Arrow', 'format']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'Arrow', 'fromdate']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'Arrow', 'fromdatetime']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'Arrow', 'fromordinal']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'Arrow', 'fromtimestamp']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'Arrow', 'gather_timeframes']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'Arrow', 'humanize']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'Arrow', 'imaginary']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'Arrow', 'int_timestamp']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'Arrow', 'interval']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'Arrow', 'isocalendar']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'Arrow', 'isoformat']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'Arrow', 'isoweekday']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'Arrow', 'naive']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'Arrow', 'range']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'Arrow', 'replace']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'Arrow', 'span']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'Arrow', 'span_range']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'Arrow', 'strftime']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'Arrow', 'strptime']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'Arrow', 'timestamp']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'Arrow', 'toordinal']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'Arrow', 'tzinfo']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'Arrow', 'utcfromtimestamp']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'Arrow', 'weekday']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'date']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'fold']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'timestamp']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'arrow', 'tzinfo']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'factory', 'ArrowFactory']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'formatter', 'DateTimeFormatter', '_format_token']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'formatter', 'DateTimeFormatter', 'format']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'formatter', 'FORMAT_ATOM']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'formatter', 'FORMAT_COOKIE']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'formatter', 'FORMAT_RFC1036']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'formatter', 'FORMAT_RFC1123']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'formatter', 'FORMAT_RFC2822']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'formatter', 'FORMAT_RFC3339']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'formatter', 'FORMAT_RFC822']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'formatter', 'FORMAT_RFC850']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'formatter', 'FORMAT_RSS']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'formatter', 'FORMAT_W3C']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'locales', 'Locale', '_name_to_ordinal']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'locales', 'Locale', 'day_name']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'locales', 'Locale', 'month_name']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'parser', 'DateTimeParser', '__init__']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'parser', 'DateTimeParser', '_build_datetime']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'parser', 'DateTimeParser', '_generate_choice_re']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'parser', 'DateTimeParser', '_generate_pattern_re']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'parser', 'DateTimeParser', '_parse_multiformat']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'parser', 'DateTimeParser', '_parse_token']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'parser', 'DateTimeParser', 'parse']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'parser', 'DateTimeParser', 'parse_iso']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'parser', 'ParserError']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'parser', 'ParserMatchError']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'parser', 'TzinfoParser']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'parser', 'TzinfoParser', 'parse']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'arrow', 'parser', '_Parts']
# 1
# /home
# ['', 'home', 'wsys', 'ServerlessApp', 'ServerlessApp-main20220225', 'testAPP', 'main', 'lambda_handler']
# 1
# /home
# ['arrow']
# 2
# ['arrow', '__init__']
# 1
# arrow/__init__
# ['arrow', '__init__', '__version__']
# 1
# arrow/__init__
# ['arrow', '__init__', 'get']
# 1
# arrow/__init__
# ['arrow', '__init__', 'now']
# 1
# arrow/__init__
# ['arrow', '__version__']
# 1
# arrow/__version__
# ['arrow', 'api']
# 1
# arrow/api
# ['arrow', 'api', 'get']
# 1
# arrow/api
# ['arrow', 'api', 'now']
# 1
# arrow/api
# ['arrow', 'arrow']
# 1
# arrow/arrow
# ['arrow', 'arrow', 'Arrow']
# 1
# arrow/arrow
# ['arrow', 'arrow', 'Arrow', '__init__']
# 1
# arrow/arrow
# ['arrow', 'arrow', 'Arrow', 'format']
# 1
# arrow/arrow
# ['arrow', 'arrow', 'Arrow', 'fromdate']
# 1
# arrow/arrow
# ['arrow', 'arrow', 'Arrow', 'fromdatetime']
# 1
# arrow/arrow
# ['arrow', 'arrow', 'Arrow', 'fromtimestamp']
# 1
# arrow/arrow
# ['arrow', 'arrow', 'Arrow', 'now']
# 1
# arrow/arrow
# ['arrow', 'arrow', 'Arrow', 'utcfromtimestamp']
# 1
# arrow/arrow
# ['arrow', 'arrow', 'Arrow', 'utcnow']
# 1
# arrow/arrow
# ['arrow', 'arrow', 'TZ_EXPR']
# 1
# arrow/arrow
# ['arrow', 'constants']
# 1
# arrow/constants
# ['arrow', 'constants', 'DEFAULT_LOCALE']
# 1
# arrow/constants
# ['arrow', 'constants', 'MAX_TIMESTAMP']
# 1
# arrow/constants
# ['arrow', 'constants', 'MAX_TIMESTAMP_MS']
# 1
# arrow/constants
# ['arrow', 'constants', 'MAX_TIMESTAMP_US']
# 1
# arrow/constants
# ['arrow', 'factory']
# 1
# arrow/factory
# ['arrow', 'factory', 'ArrowFactory']
# 1
# arrow/factory
# ['arrow', 'factory', 'ArrowFactory', '__init__']
# 1
# arrow/factory
# ['arrow', 'factory', 'ArrowFactory', 'get']
# 1
# arrow/factory
# ['arrow', 'factory', 'ArrowFactory', 'now']
# 1
# arrow/factory
# ['arrow', 'formatter']
# 1
# arrow/formatter
# ['arrow', 'formatter', 'DateTimeFormatter']
# 1
# arrow/formatter
# ['arrow', 'formatter', 'DateTimeFormatter', '__init__']
# 1
# arrow/formatter
# ['arrow', 'formatter', 'DateTimeFormatter', 'format']
# 1
# arrow/formatter
# ['arrow', 'get']
# 1
# arrow/get
# ['arrow', 'locales']
# 1
# arrow/locales
# ['arrow', 'locales', 'Locale']
# 1
# arrow/locales
# ['arrow', 'locales', 'TimeFrameLiteral']
# 1
# arrow/locales
# ['arrow', 'locales', 'get_locale']
# 1
# arrow/locales
# ['arrow', 'now']
# 1
# arrow/now
# ['arrow', 'parser']
# 1
# arrow/parser
# ['arrow', 'parser', 'DateTimeParser']
# 1
# arrow/parser
# ['arrow', 'parser', 'DateTimeParser', '__init__']
# 1
# arrow/parser
# ['arrow', 'parser', 'DateTimeParser', '_build_datetime']
# 1
# arrow/parser
# ['arrow', 'parser', 'DateTimeParser', '_generate_pattern_re']
# 1
# arrow/parser
# ['arrow', 'parser', 'DateTimeParser', '_parse_multiformat']
# 1
# arrow/parser
# ['arrow', 'parser', 'DateTimeParser', '_parse_token']
# 1
# arrow/parser
# ['arrow', 'parser', 'DateTimeParser', 'parse']
# 1
# arrow/parser
# ['arrow', 'parser', 'DateTimeParser', 'parse_iso']
# 1
# arrow/parser
# ['arrow', 'parser', 'TzinfoParser']
# 1
# arrow/parser
# ['arrow', 'parser', 'TzinfoParser', 'parse']
# 1
# arrow/parser
# ['arrow', 'util']
# 1
# arrow/util
# ['arrow', 'util', 'is_timestamp']
# 1
# arrow/util
# ['arrow', 'util', 'iso_to_gregorian']
# 1
# arrow/util
# ['arrow', 'util', 'next_weekday']
# 1
# arrow/util
# ['arrow', 'util', 'normalize_timestamp']
# 1
# arrow/util
# ['calendar']
# 2
# ['calendar', 'timegm']
# 1
# calendar/timegm
# ['datetime']
# 2
# ['datetime', 'date']
# 1
# datetime/date
# ['datetime', 'date', 'day']
# 1
# datetime/date
# ['datetime', 'date', 'month']
# 1
# datetime/date
# ['datetime', 'date', 'year']
# 1
# datetime/date
# ['datetime', 'datetime']
# 1
# datetime/datetime
# ['datetime', 'datetime', 'fromtimestamp']
# 1
# datetime/datetime
# ['datetime', 'datetime', 'max']
# 1
# datetime/datetime
# ['datetime', 'datetime', 'max', 'timestamp']
# 1
# datetime/datetime
# ['datetime', 'datetime', 'max', 'toordinal']
# 1
# datetime/datetime
# ['datetime', 'datetime', 'min']
# 1
# datetime/datetime
# ['datetime', 'datetime', 'now']
# 1
# datetime/datetime
# ['datetime', 'datetime', 'resolution']
# 1
# datetime/datetime
# ['datetime', 'datetime', 'strptime']
# 1
# datetime/datetime
# ['datetime', 'datetime', 'utcfromtimestamp']
# 1
# datetime/datetime
# ['datetime', 'timedelta']
# 1
# datetime/timedelta
# ['datetime', 'tzinfo']
# 1
# datetime/tzinfo
# ['dateutil', 'rrule', 'WEEKLY']
# 1
# dateutil/rrule
# ['dateutil', 'rrule', 'rrule']
# 1
# dateutil/rrule
# ['dateutil', 'tz']
# 1
# dateutil/tz
# ['dateutil', 'tz', 'gettz']
# 1
# dateutil/tz
# ['dateutil', 'tz', 'tzlocal']
# 1
# dateutil/tz
# ['dateutil', 'tz', 'tzoffset']
# 1
# dateutil/tz
# ['dateutil', 'tz', 'tzutc']
# 1
# dateutil/tz
# ['decimal', 'Decimal']
# 1
# decimal/Decimal
# ['functools', 'lru_cache']
# 1
# functools/lru_cache
# ['logging']
# 2
# ['logging', 'INFO']
# 1
# logging/INFO
# ['logging', 'getLogger']
# 1
# logging/getLogger
# ['main']
# 2
# ['main', 'lambda_handler']
# 1
# main/lambda_handler
# ['re']
# 2
# ['re', 'IGNORECASE']
# 1
# re/IGNORECASE
# ['re', 'compile']
# 1
# re/compile
# ['re', 'error']
# 1
# re/error
# ['re', 'escape']
# 1
# re/escape
# ['re', 'findall']
# 1
# re/findall
# ['re', 'split']
# 1
# re/split
# ['re', 'sub']
# 1
# re/sub
# ['sys']
# 2
# ['sys', 'maxsize']
# 1
# sys/maxsize
# ['sys', 'version_info']
# 1
# sys/version_info
# ['time']
# 2
# ['time', 'struct_time']
# 1
# time/struct_time
# ['time', 'time']
# 1
# time/time
# ['typing', 'Any']
# 1
# typing/Any
# ['typing', 'ClassVar']
# 1
# typing/ClassVar
# ['typing', 'Dict']
# 1
# typing/Dict
# ['typing', 'Final']
# 1
# typing/Final
# ['typing', 'Iterable']
# 1
# typing/Iterable
# ['typing', 'List']
# 1
# typing/List
# ['typing', 'Literal']
# 1
# typing/Literal
# ['typing', 'Mapping']
# 1
# typing/Mapping
# ['typing', 'Match']
# 1
# typing/Match
# ['typing', 'Optional']
# 1
# typing/Optional
# ['typing', 'Pattern']
# 1
# typing/Pattern
# ['typing', 'Sequence']
# 1
# typing/Sequence
# ['typing', 'SupportsFloat']
# 1
# typing/SupportsFloat
# ['typing', 'SupportsInt']
# 1
# typing/SupportsInt
# ['typing', 'Tuple']
# 1
# typing/Tuple
# ['typing', 'Type']
# 1
# typing/Type
# ['typing', 'Union']
# 1
# typing/Union
# ['typing', 'cast']
# 1
# typing/cast
# ['typing', 'overload']
# 1
# typing/overload
# ['typing_extensions', 'Final']
# 1
# typing_extensions/Final
# ['typing_extensions', 'Literal']
# 1
# typing_extensions/Literal
# ['', 'arrow']

# %%
moshu_file_update= "moshu_functions/{}_update.txt".format(Identify_name)
os.system("python3 find_moshu.py --dirname {} --path {} --packageset {} --moshuoutput {}".format(dir_name, input_package, used_package_name, moshu_file_update))
# Out:
# ['arrow']
# testAPP/main.py
# testAPP/six.py
# testAPP/custom_funtemplate.py
# testAPP/lazy_import/__init__.py
# testAPP/arrow/_version.py
# testAPP/arrow/constants.py
# testAPP/arrow/parser.py
# testAPP/arrow/util.py
# testAPP/arrow/factory.py
# testAPP/arrow/locales.py
# testAPP/arrow/api.py
# testAPP/arrow/formatter.py
# testAPP/arrow/__init__.py
# testAPP/arrow/arrow.py
# []
# 0

# %%
special_key=["requests.utils.set_environ", 
"requests.sessions.Session.request", 
"requests.adapters.HTTPAdapter.send", 
"urllib3.connectionpool.connection_from_url",
"numpy.linalg.lapack_lite", 
"numpy.lib._iotools.NameValidator",
"numpy.lib._iotools._decode_line",
"numpy.lib._iotools.easy_dtype",
"numpy.lib.npyio.loadtxt",
"numpy.lib.npyio.loadtxt.flatten_dtype_internal",
"numpy.lib.npyio.loadtxt.read_data",
"numpy.lib.npyio.loadtxt.pack_items",
"numpy.lib.npyio.loadtxt.split_line",
"mpl_toolkits.axes_grid1.parasite_axes.host_axes_class_factory",
"sklearn.ensemble._forest._parallel_build_trees",
"pandas.io.parsers._read",
"pandas.io.excel._xlwt._XlwtWriter",
"pandas.io.excel._xlsxwriter._XlsxWriter",
"pandas.io.excel._openpyxl._OpenpyxlWriter",
"pandas.io.excel._odswriter._ODSWriter",
"pandas.io.excel._base.ExcelWriter",
"tensorflow.python.platform.resource_loader.get_path_to_datafile",
"tensorflow.python.training.saving.saveable_object_util.saveable_objects_for_op",
"tensorflow.python.keras.saving.saved_model.serialized_attributes.CommonEndpoints",
"tensorflow.python.training.saver.BaseSaverBuilder",
"tensorflow.python.summary.writer.writer.FileWriter",
"tensorflow.python.keras.engine.base_layer.Layer",
"urllib3.request.RequestMethods",
"keras.saving.saved_model.load_context.load_context",
"absl.third_party.unittest3_backport.result.TextTestResult",
"keras.optimizer_v1.Optimizer"
]

# %%
moshu_file_final = "moshu_functions/{}_final.txt".format(Identify_name)
dynamicprocess.moshu_update(moshu_file_update, special_key, moshu_file_final)

# %% [markdown]
# step 7

# %%
used_fun_result_output_update = "used_func_result/used_func_{}_update.txt".format(Identify_name)
dynamicprocess.getDynamicContent(seedfun_list, input_package, re_FunRel, input_entry_point, moshu_file_final, used_fun_result_output_update)

used_fun_result_output_final = "used_func_result/used_func_{}_final.txt".format(Identify_name)
# Out:
# start magic
# processing---------------testAPP/main.py
# ====================================================
# ['main', 'main.lambda_handler']
# 1----cunzai
# 1----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# ['arrow.formatter', 'arrow.arrow', 'arrow.__init__', 'arrow.util', 'main', 'arrow.parser', 'arrow.api', 'arrow.constants', 'arrow.factory', 'arrow.locales']
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# ['.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.toordinal', 'arrow.parser.DateTimeParser.parse', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow._get_frames', 'arrow.locales.TimeFrameLiteral', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow', 'arrow.arrow.Arrow', 'arrow.arrow.Arrow.fromdatetime', 'typing.Iterable', 'datetime.datetime.strptime', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.formatter.FORMAT_W3C', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.formatter.DateTimeFormatter.format', 'arrow.arrow.Arrow.__init__', 'time.struct_time', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.fold', 'arrow.formatter.DateTimeFormatter.__init__', 'typing.ClassVar', 'typing.Pattern', 'arrow.parser.TzinfoParser.parse', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.format', 'typing_extensions.Literal', 'arrow.parser.DateTimeParser._parse_multiformat', 're.split', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.fromordinal', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.weekday', '<builtin>.TypeError', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.utcfromtimestamp', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.dehumanize', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.locales.Locale.month_name', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.strftime', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.formatter.DateTimeFormatter._format_token', 'arrow.__init__.__version__', 'arrow.arrow.Arrow.fromdate', 'arrow.parser.DateTimeParser.parse_iso', '<builtin>.getattr', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.main.lambda_handler', 're.IGNORECASE', 'arrow.formatter.DateTimeFormatter', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.__hash__', 'typing.Match', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.formatter.FORMAT_RSS', 'dateutil.tz.tzoffset', 'dateutil.tz.tzlocal', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.__format__', 'datetime.tzinfo', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.isoweekday', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.parser.DateTimeParser._generate_pattern_re', 'datetime.datetime.max.timestamp', 'arrow.util', 'datetime.datetime.max', 'arrow.api', 'typing.Tuple', 'calendar.timegm', 'datetime.date', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.parser.TzinfoParser.parse', 'arrow.parser.DateTimeParser._parse_token', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.interval', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.__radd__', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.parser._Parts', 'typing.Sequence', 'typing.SupportsInt', 're.error', 'arrow.parser.DateTimeParser.__init__', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.formatter.FORMAT_COOKIE', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.span', 'typing.Optional', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.api.utcnow', 'decimal.Decimal', 'arrow.parser.DateTimeParser', 'arrow.now', 'arrow.factory.ArrowFactory.now', 'arrow.get', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.parser.ParserMatchError', 'arrow.arrow.Arrow.utcfromtimestamp', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.strptime', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.int_timestamp', 'main', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow ...
# end====================================================
# find possible note
# start
# start=====1===========
# ['', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.toordinal', 'arrow.parser.DateTimeParser.parse', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow._get_frames', 'arrow.locales.TimeFrameLiteral', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow', 'arrow.arrow.Arrow', 'arrow.arrow.Arrow.fromdatetime', 'typing.Iterable', 'datetime.datetime.strptime', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.formatter.FORMAT_W3C', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.formatter.DateTimeFormatter.format', 'arrow.arrow.Arrow.__init__', 'time.struct_time', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.fold', 'arrow.formatter.DateTimeFormatter.__init__', 'typing.ClassVar', 'typing.Pattern', 'arrow.parser.TzinfoParser.parse', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.format', 'typing_extensions.Literal', 'arrow.parser.DateTimeParser._parse_multiformat', 're.split', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.fromordinal', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.weekday', '<builtin>.TypeError', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.utcfromtimestamp', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.dehumanize', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.locales.Locale.month_name', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.strftime', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.formatter.DateTimeFormatter._format_token', 'arrow.__init__.__version__', 'arrow.arrow.Arrow.fromdate', 'arrow.parser.DateTimeParser.parse_iso', '<builtin>.getattr', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.main.lambda_handler', 're.IGNORECASE', 'arrow.formatter.DateTimeFormatter', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.__hash__', 'typing.Match', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.formatter.FORMAT_RSS', 'dateutil.tz.tzoffset', 'dateutil.tz.tzlocal', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.__format__', 'datetime.tzinfo', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.isoweekday', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.parser.DateTimeParser._generate_pattern_re', 'datetime.datetime.max.timestamp', 'arrow.util', 'datetime.datetime.max', 'arrow.api', 'typing.Tuple', 'datetime.date', 'calendar.timegm', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.parser.TzinfoParser.parse', 'arrow.parser.DateTimeParser._parse_token', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.interval', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.__radd__', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.parser._Parts', 'typing.Sequence', 'typing.SupportsInt', 're.error', 'arrow.parser.DateTimeParser.__init__', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.formatter.FORMAT_COOKIE', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.span', 'typing.Optional', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.api.utcnow', 'decimal.Decimal', 'arrow.parser.DateTimeParser', 'arrow.now', 'arrow.factory.ArrowFactory.now', 'arrow.get', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.parser.ParserMatchError', 'arrow.arrow.Arrow.utcfromtimestamp', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.strptime', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.int_timestamp', 'main', '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.A ...
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# ['arrow.formatter', 'arrow.arrow', 'arrow.__init__', 'arrow.util', 'main', 'arrow.parser', 'arrow.api', 'arrow.constants', 'arrow.factory', 'arrow.locales']
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 1----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 2----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 3----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 4----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 5----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 6----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 7----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 8----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# 9----cunzai
# write in
# done！

# %% [markdown]
# step 8

# %%
# OK Step 8, process output information
special_key_append = ["unittest.TestCase"]
dynamicprocess.result_process(input_package, used_fun_result_output_update,used_fun_result_output_final, special_key_append)
# Out:
# -------------
#
# (0, 'testAPP.', 0)
#
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow._version.__version__
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow._version.__version__
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.api.get
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.api.get
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.api.now
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.api.now
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.api.utcnow
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.api.utcnow
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.__add__
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.__add__
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.__format__
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.__format__
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.__getattr__
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.__getattr__
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.__hash__
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.__hash__
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.__radd__
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.__radd__
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.__str__
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.__str__
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow._get_datetime
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow._get_datetime
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow._get_frames
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow._get_frames
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow._get_iteration_params
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow._get_iteration_params
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow._get_tzinfo
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow._get_tzinfo
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow._is_last_day_of_month
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow._is_last_day_of_month
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.ambiguous
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.ambiguous
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.astimezone
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.astimezone
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.date
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.date
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.datetime
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.datetime
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.dehumanize
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.dehumanize
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.float_timestamp
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.float_timestamp
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.fold
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.fold
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.format
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.format
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.fromdate
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.fromdate
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.fromdatetime
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.fromdatetime
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.fromordinal
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.fromordinal
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.fromtimestamp
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.fromtimestamp
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.gather_timeframes
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.gather_timeframes
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.humanize
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.humanize
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.imaginary
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.imaginary
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.int_timestamp
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.int_timestamp
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.interval
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.interval
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.isocalendar
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.isocalendar
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.isoformat
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.isoformat
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.isoweekday
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.isoweekday
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.naive
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.naive
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.range
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.range
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.replace
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.replace
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.span
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.span
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.span_range
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.span_range
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.strftime
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.strftime
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.strptime
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.strptime
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.timestamp
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.timestamp
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.toordinal
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.toordinal
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.tzinfo
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.tzinfo
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.utcfromtimestamp
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.utcfromtimestamp
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.weekday
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.weekday
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.date
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.date
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.fold
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.fold
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.timestamp
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.timestamp
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.tzinfo
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.tzinfo
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.factory.ArrowFactory
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.factory.ArrowFactory
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.formatter.DateTimeFormatter._format_token
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.formatter.DateTimeFormatter._format_token
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.formatter.DateTimeFormatter.format
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.formatter.DateTimeFormatter.format
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.formatter.FORMAT_ATOM
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.formatter.FORMAT_ATOM
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.formatter.FORMAT_COOKIE
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.formatter.FORMAT_COOKIE
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.formatter.FORMAT_RFC1036
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.formatter.FORMAT_RFC1036
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.formatter.FORMAT_RFC1123
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.formatter.FORMAT_RFC1123
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.formatter.FORMAT_RFC2822
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.formatter.FORMAT_RFC2822
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.formatter.FORMAT_RFC3339
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.formatter.FORMAT_RFC3339
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.formatter.FORMAT_RFC822
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.formatter.FORMAT_RFC822
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.formatter.FORMAT_RFC850
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.formatter.FORMAT_RFC850
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.formatter.FORMAT_RSS
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.formatter.FORMAT_RSS
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.formatter.FORMAT_W3C
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.formatter.FORMAT_W3C
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.locales.Locale._name_to_ordinal
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.locales.Locale._name_to_ordinal
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.locales.Locale.day_name
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.locales.Locale.day_name
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.locales.Locale.month_name
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.locales.Locale.month_name
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.parser.DateTimeParser.__init__
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.parser.DateTimeParser.__init__
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.parser.DateTimeParser
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.parser.DateTimeParser._build_datetime
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.parser.DateTimeParser._build_datetime
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.parser.DateTimeParser._generate_choice_re
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.parser.DateTimeParser._generate_choice_re
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.parser.DateTimeParser._generate_pattern_re
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.parser.DateTimeParser._generate_pattern_re
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.parser.DateTimeParser._parse_multiformat
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.parser.DateTimeParser._parse_multiformat
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.parser.DateTimeParser._parse_token
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.parser.DateTimeParser._parse_token
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.parser.DateTimeParser.parse
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.parser.DateTimeParser.parse
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.parser.DateTimeParser.parse_iso
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.parser.DateTimeParser.parse_iso
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.parser.ParserError
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.parser.ParserError
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.parser.ParserMatchError
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.parser.ParserMatchError
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.parser.TzinfoParser
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.parser.TzinfoParser
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.parser.TzinfoParser.parse
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.parser.TzinfoParser.parse
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.parser._Parts
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.parser._Parts
# -------------
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.main.lambda_handler
# (0, 'testAPP..home', 1)
# .home.wsys.ServerlessApp.ServerlessApp-main20220225.main.lambda_handler
# -------------
# arrow
# (3, 'testAPP.arrow.__init__', 0)
# arrow.__init__
# arrow
# -------------
# arrow.__init__
# (1, 'testAPP.arrow.__init__', 1)
# arrow.__init__
# arrow
# -------------
# arrow.__init__.__version__
# (1, 'testAPP.arrow.__init__', 1)
# arrow.__init__.__version__
# -------------
# arrow.__init__.get
# (1, 'testAPP.arrow.__init__', 1)
# arrow.__init__.get
# -------------
# arrow.__init__.now
# (1, 'testAPP.arrow.__init__', 1)
# arrow.__init__.now
# -------------
# arrow.__version__
# (2, 'testAPP.arrow.__init__', 0)
# arrow.__init__.__version__
# -------------
# arrow.api
# (1, 'testAPP.arrow.api', 1)
# arrow.api
# -------------
# arrow.api.get
# (1, 'testAPP.arrow.api', 1)
# arrow.api.get
# -------------
# arrow.api.now
# (1, 'testAPP.arrow.api', 1)
# arrow.api.now
# -------------
# arrow.arrow
# (1, 'testAPP.arrow.arrow', 1)
# arrow.arrow
# -------------
# arrow.arrow.Arrow
# (1, 'testAPP.arrow.arrow', 1)
# arrow.arrow.Arrow
# -------------
# arrow.arrow.Arrow.__init__
# (1, 'testAPP.arrow.arrow', 1)
# arrow.arrow.Arrow.__init__
# arrow.arrow.Arrow
# -------------
# arrow.arrow.Arrow.format
# (1, 'testAPP.arrow.arrow', 1)
# arrow.arrow.Arrow.format
# -------------
# arrow.arrow.Arrow.fromdate
# (1, 'testAPP.arrow.arrow', 1)
# arrow.arrow.Arrow.fromdate
# -------------
# arrow.arrow.Arrow.fromdatetime
# (1, 'testAPP.arrow.arrow', 1)
# arrow.arrow.Arrow.fromdatetime
# -------------
# arrow.arrow.Arrow.fromtimestamp
# (1, 'testAPP.arrow.arrow', 1)
# arrow.arrow.Arrow.fromtimestamp
# -------------
# arrow.arrow.Arrow.now
# (1, 'testAPP.arrow.arrow', 1)
# arrow.arrow.Arrow.now
# -------------
# arrow.arrow.Arrow.utcfromtimestamp
# (1, 'testAPP.arrow.arrow', 1)
# arrow.arrow.Arrow.utcfromtimestamp
# -------------
# arrow.arrow.Arrow.utcnow
# (1, 'testAPP.arrow.arrow', 1)
# arrow.arrow.Arrow.utcnow
# -------------
# arrow.arrow.TZ_EXPR
# (1, 'testAPP.arrow.arrow', 1)
# arrow.arrow.TZ_EXPR
# -------------
# arrow.constants
# (1, 'testAPP.arrow.constants', 1)
# arrow.constants
# -------------
# arrow.constants.DEFAULT_LOCALE
# (1, 'testAPP.arrow.constants', 1)
# arrow.constants.DEFAULT_LOCALE
# -------------
# arrow.constants.MAX_TIMESTAMP
# (1, 'testAPP.arrow.constants', 1)
# arrow.constants.MAX_TIMESTAMP
# -------------
# arrow.constants.MAX_TIMESTAMP_MS
# (1, 'testAPP.arrow.constants', 1)
# arrow.constants.MAX_TIMESTAMP_MS
# -------------
# arrow.constants.MAX_TIMESTAMP_US
# (1, 'testAPP.arrow.constants', 1)
# arrow.constants.MAX_TIMESTAMP_US
# -------------
# arrow.factory
# (1, 'testAPP.arrow.factory', 1)
# arrow.factory
# -------------
# arrow.factory.ArrowFactory
# (1, 'testAPP.arrow.factory', 1)
# arrow.factory.ArrowFactory
# -------------
# arrow.factory.ArrowFactory.__init__
# (1, 'testAPP.arrow.factory', 1)
# arrow.factory.ArrowFactory.__init__
# arrow.factory.ArrowFactory
# -------------
# arrow.factory.ArrowFactory.get
# (1, 'testAPP.arrow.factory', 1)
# arrow.factory.ArrowFactory.get
# -------------
# arrow.factory.ArrowFactory.now
# (1, 'testAPP.arrow.factory', 1)
# arrow.factory.ArrowFactory.now
# -------------
# arrow.formatter
# (1, 'testAPP.arrow.formatter', 1)
# arrow.formatter
# -------------
# arrow.formatter.DateTimeFormatter
# (1, 'testAPP.arrow.formatter', 1)
# arrow.formatter.DateTimeFormatter
# -------------
# arrow.formatter.DateTimeFormatter.__init__
# (1, 'testAPP.arrow.formatter', 1)
# arrow.formatter.DateTimeFormatter.__init__
# arrow.formatter.DateTimeFormatter
# -------------
# arrow.formatter.DateTimeFormatter.format
# (1, 'testAPP.arrow.formatter', 1)
# arrow.formatter.DateTimeFormatter.format
# -------------
# arrow.get
# (2, 'testAPP.arrow.__init__', 0)
# arrow.__init__.get
# -------------
# arrow.locales
# (1, 'testAPP.arrow.locales', 1)
# arrow.locales
# -------------
# arrow.locales.Locale
# (1, 'testAPP.arrow.locales', 1)
# arrow.locales.Locale
# -------------
# arrow.locales.TimeFrameLiteral
# (1, 'testAPP.arrow.locales', 1)
# arrow.locales.TimeFrameLiteral
# -------------
# arrow.locales.get_locale
# (1, 'testAPP.arrow.locales', 1)
# arrow.locales.get_locale
# -------------
# arrow.now
# (2, 'testAPP.arrow.__init__', 0)
# arrow.__init__.now
# -------------
# arrow.parser
# (1, 'testAPP.arrow.parser', 1)
# arrow.parser
# -------------
# arrow.parser.DateTimeParser
# (1, 'testAPP.arrow.parser', 1)
# arrow.parser.DateTimeParser
# -------------
# arrow.parser.DateTimeParser.__init__
# (1, 'testAPP.arrow.parser', 1)
# arrow.parser.DateTimeParser.__init__
# arrow.parser.DateTimeParser
# -------------
# arrow.parser.DateTimeParser._build_datetime
# (1, 'testAPP.arrow.parser', 1)
# arrow.parser.DateTimeParser._build_datetime
# -------------
# arrow.parser.DateTimeParser._generate_pattern_re
# (1, 'testAPP.arrow.parser', 1)
# arrow.parser.DateTimeParser._generate_pattern_re
# -------------
# arrow.parser.DateTimeParser._parse_multiformat
# (1, 'testAPP.arrow.parser', 1)
# arrow.parser.DateTimeParser._parse_multiformat
# -------------
# arrow.parser.DateTimeParser._parse_token
# (1, 'testAPP.arrow.parser', 1)
# arrow.parser.DateTimeParser._parse_token
# -------------
# arrow.parser.DateTimeParser.parse
# (1, 'testAPP.arrow.parser', 1)
# arrow.parser.DateTimeParser.parse
# -------------
# arrow.parser.DateTimeParser.parse_iso
# (1, 'testAPP.arrow.parser', 1)
# arrow.parser.DateTimeParser.parse_iso
# -------------
# arrow.parser.TzinfoParser
# (1, 'testAPP.arrow.parser', 1)
# arrow.parser.TzinfoParser
# -------------
# arrow.parser.TzinfoParser.parse
# (1, 'testAPP.arrow.parser', 1)
# arrow.parser.TzinfoParser.parse
# -------------
# arrow.util
# (1, 'testAPP.arrow.util', 1)
# arrow.util
# -------------
# arrow.util.is_timestamp
# (1, 'testAPP.arrow.util', 1)
# arrow.util.is_timestamp
# -------------
# arrow.util.iso_to_gregorian
# (1, 'testAPP.arrow.util', 1)
# arrow.util.iso_to_gregorian
# -------------
# arrow.util.next_weekday
# (1, 'testAPP.arrow.util', 1)
# arrow.util.next_weekday
# -------------
# arrow.util.normalize_timestamp
# (1, 'testAPP.arrow.util', 1)
# arrow.util.normalize_timestamp
# -------------
# calendar
# (0, 'testAPP.calendar', 0)
# calendar
# -------------
# calendar.timegm
# (0, 'testAPP.calendar', 0)
# calendar.timegm
# -------------
# datetime
# (0, 'testAPP.datetime', 0)
# datetime
# -------------
# datetime.date
# (0, 'testAPP.datetime', 0)
# datetime.date
# -------------
# datetime.date.day
# (0, 'testAPP.datetime', 0)
# datetime.date.day
# -------------
# datetime.date.month
# (0, 'testAPP.datetime', 0)
# datetime.date.month
# -------------
# datetime.date.year
# (0, 'testAPP.datetime', 0)
# datetime.date.year
# -------------
# datetime.datetime
# (0, 'testAPP.datetime', 0)
# datetime.datetime
# -------------
# datetime.datetime.fromtimestamp
# (0, 'testAPP.datetime', 0)
# datetime.datetime.fromtimestamp
# -------------
# datetime.datetime.max
# (0, 'testAPP.datetime', 0)
# datetime.datetime.max
# -------------
# datetime.datetime.max.timestamp
# (0, 'testAPP.datetime', 0)
# datetime.datetime.max.timestamp
# -------------
# datetime.datetime.max.toordinal
# (0, 'testAPP.datetime', 0)
# datetime.datetime.max.toordinal
# -------------
# datetime.datetime.min
# (0, 'testAPP.datetime', 0)
# datetime.datetime.min
# -------------
# datetime.datetime.now
# (0, 'testAPP.datetime', 0)
# datetime.datetime.now
# -------------
# datetime.datetime.resolution
# (0, 'testAPP.datetime', 0)
# datetime.datetime.resolution
# -------------
# datetime.datetime.strptime
# (0, 'testAPP.datetime', 0)
# datetime.datetime.strptime
# -------------
# datetime.datetime.utcfromtimestamp
# (0, 'testAPP.datetime', 0)
# datetime.datetime.utcfromtimestamp
# -------------
# datetime.timedelta
# (0, 'testAPP.datetime', 0)
# datetime.timedelta
# -------------
# datetime.tzinfo
# (0, 'testAPP.datetime', 0)
# datetime.tzinfo
# -------------
# dateutil.rrule.WEEKLY
# (0, 'testAPP.dateutil', 0)
# dateutil.rrule.WEEKLY
# -------------
# dateutil.rrule.rrule
# (0, 'testAPP.dateutil', 0)
# dateutil.rrule.rrule
# -------------
# dateutil.tz
# (0, 'testAPP.dateutil', 0)
# dateutil.tz
# -------------
# dateutil.tz.gettz
# (0, 'testAPP.dateutil', 0)
# dateutil.tz.gettz
# -------------
# dateutil.tz.tzlocal
# (0, 'testAPP.dateutil', 0)
# dateutil.tz.tzlocal
# -------------
# dateutil.tz.tzoffset
# (0, 'testAPP.dateutil', 0)
# dateutil.tz.tzoffset
# -------------
# dateutil.tz.tzutc
# (0, 'testAPP.dateutil', 0)
# dateutil.tz.tzutc
# -------------
# decimal.Decimal
# (0, 'testAPP.decimal', 0)
# decimal.Decimal
# -------------
# functools.lru_cache
# (0, 'testAPP.functools', 0)
# functools.lru_cache
# -------------
# logging
# (0, 'testAPP.logging', 0)
# logging
# -------------
# logging.INFO
# (0, 'testAPP.logging', 0)
# logging.INFO
# -------------
# logging.getLogger
# (0, 'testAPP.logging', 0)
# logging.getLogger
# -------------
# main
# (1, 'testAPP.main', 0)
# main
# -------------
# main.lambda_handler
# (1, 'testAPP.main', 0)
# main.lambda_handler
# -------------
# re
# (0, 'testAPP.re', 0)
# re
# -------------
# re.IGNORECASE
# (0, 'testAPP.re', 0)
# re.IGNORECASE
# -------------
# re.compile
# (0, 'testAPP.re', 0)
# re.compile
# -------------
# re.error
# (0, 'testAPP.re', 0)
# re.error
# -------------
# re.escape
# (0, 'testAPP.re', 0)
# re.escape
# -------------
# re.findall
# (0, 'testAPP.re', 0)
# re.findall
# -------------
# re.split
# (0, 'testAPP.re', 0)
# re.split
# -------------
# re.sub
# (0, 'testAPP.re', 0)
# re.sub
# -------------
# sys
# (0, 'testAPP.sys', 0)
# sys
# -------------
# sys.maxsize
# (0, 'testAPP.sys', 0)
# sys.maxsize
# -------------
# sys.version_info
# (0, 'testAPP.sys', 0)
# sys.version_info
# -------------
# time
# (0, 'testAPP.time', 0)
# time
# -------------
# time.struct_time
# (0, 'testAPP.time', 0)
# time.struct_time
# -------------
# time.time
# (0, 'testAPP.time', 0)
# time.time
# -------------
# typing.Any
# (0, 'testAPP.typing', 0)
# typing.Any
# -------------
# typing.ClassVar
# (0, 'testAPP.typing', 0)
# typing.ClassVar
# -------------
# typing.Dict
# (0, 'testAPP.typing', 0)
# typing.Dict
# -------------
# typing.Final
# (0, 'testAPP.typing', 0)
# typing.Final
# -------------
# typing.Iterable
# (0, 'testAPP.typing', 0)
# typing.Iterable
# -------------
# typing.List
# (0, 'testAPP.typing', 0)
# typing.List
# -------------
# typing.Literal
# (0, 'testAPP.typing', 0)
# typing.Literal
# -------------
# typing.Mapping
# (0, 'testAPP.typing', 0)
# typing.Mapping
# -------------
# typing.Match
# (0, 'testAPP.typing', 0)
# typing.Match
# -------------
# typing.Optional
# (0, 'testAPP.typing', 0)
# typing.Optional
# -------------
# typing.Pattern
# (0, 'testAPP.typing', 0)
# typing.Pattern
# -------------
# typing.Sequence
# (0, 'testAPP.typing', 0)
# typing.Sequence
# -------------
# typing.SupportsFloat
# (0, 'testAPP.typing', 0)
# typing.SupportsFloat
# -------------
# typing.SupportsInt
# (0, 'testAPP.typing', 0)
# typing.SupportsInt
# -------------
# typing.Tuple
# (0, 'testAPP.typing', 0)
# typing.Tuple
# -------------
# typing.Type
# (0, 'testAPP.typing', 0)
# typing.Type
# -------------
# typing.Union
# (0, 'testAPP.typing', 0)
# typing.Union
# -------------
# typing.cast
# (0, 'testAPP.typing', 0)
# typing.cast
# -------------
# typing.overload
# (0, 'testAPP.typing', 0)
# typing.overload
# -------------
# typing_extensions.Final
# (0, 'testAPP.typing_extensions', 0)
# typing_extensions.Final
# -------------
# typing_extensions.Literal
# (0, 'testAPP.typing_extensions', 0)
# typing_extensions.Literal
# ['',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow._version.__version__',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.api.get',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.api.now',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.api.utcnow',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.__add__',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.__format__',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.__getattr__',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.__hash__',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.__radd__',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.__str__',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow._get_datetime',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow._get_frames',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow._get_iteration_params',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow._get_tzinfo',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow._is_last_day_of_month',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.ambiguous',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.astimezone',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.date',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.datetime',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.dehumanize',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.float_timestamp',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.fold',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.format',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.fromdate',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.fromdatetime',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.fromordinal',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.fromtimestamp',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.gather_timeframes',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.humanize',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.imaginary',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.int_timestamp',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.interval',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.isocalendar',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.isoformat',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.isoweekday',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.naive',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.range',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.replace',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.span',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.span_range',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.strftime',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.strptime',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.timestamp',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.toordinal',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.tzinfo',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.utcfromtimestamp',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.Arrow.weekday',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.date',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.fold',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.timestamp',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.arrow.tzinfo',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.factory.ArrowFactory',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.formatter.DateTimeFormatter._format_token',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.formatter.DateTimeFormatter.format',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.formatter.FORMAT_ATOM',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.formatter.FORMAT_COOKIE',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.formatter.FORMAT_RFC1036',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.formatter.FORMAT_RFC1123',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.formatter.FORMAT_RFC2822',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.formatter.FORMAT_RFC3339',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.formatter.FORMAT_RFC822',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.formatter.FORMAT_RFC850',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.formatter.FORMAT_RSS',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.formatter.FORMAT_W3C',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.locales.Locale._name_to_ordinal',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.locales.Locale.day_name',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.locales.Locale.month_name',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.parser.DateTimeParser',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.parser.DateTimeParser.__init__',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.parser.DateTimeParser._build_datetime',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.parser.DateTimeParser._generate_choice_re',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.parser.DateTimeParser._generate_pattern_re',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.parser.DateTimeParser._parse_multiformat',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.parser.DateTimeParser._parse_token',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.parser.DateTimeParser.parse',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.parser.DateTimeParser.parse_iso',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.parser.ParserError',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.parser.ParserMatchError',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.parser.TzinfoParser',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.parser.TzinfoParser.parse',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.arrow.parser._Parts',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.main.lambda_handler',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow._version.__version__',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.api.get',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.api.now',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.api.utcnow',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.__add__',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.__format__',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.__getattr__',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.__hash__',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.__radd__',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.__str__',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow._get_datetime',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow._get_frames',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow._get_iteration_params',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow._get_tzinfo',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow._is_last_day_of_month',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.ambiguous',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.astimezone',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.date',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.datetime',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.dehumanize',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.float_timestamp',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.fold',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.format',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.fromdate',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.fromdatetime',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.fromordinal',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.fromtimestamp',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.gather_timeframes',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.humanize',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.imaginary',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.int_timestamp',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.interval',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.isocalendar',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.isoformat',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.isoweekday',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.naive',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.range',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.replace',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.span',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.span_range',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.strftime',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.strptime',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.timestamp',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.toordinal',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.tzinfo',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.utcfromtimestamp',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.Arrow.weekday',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.date',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.fold',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.timestamp',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.arrow.tzinfo',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.factory.ArrowFactory',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.formatter.DateTimeFormatter._format_token',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.formatter.DateTimeFormatter.format',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.formatter.FORMAT_ATOM',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.formatter.FORMAT_COOKIE',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.formatter.FORMAT_RFC1036',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.formatter.FORMAT_RFC1123',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.formatter.FORMAT_RFC2822',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.formatter.FORMAT_RFC3339',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.formatter.FORMAT_RFC822',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.formatter.FORMAT_RFC850',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.formatter.FORMAT_RSS',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.formatter.FORMAT_W3C',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.locales.Locale._name_to_ordinal',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.locales.Locale.day_name',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.locales.Locale.month_name',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.parser.DateTimeParser.__init__',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.parser.DateTimeParser._build_datetime',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.parser.DateTimeParser._generate_choice_re',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.parser.DateTimeParser._generate_pattern_re',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.parser.DateTimeParser._parse_multiformat',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.parser.DateTimeParser._parse_token',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.parser.DateTimeParser.parse',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.parser.DateTimeParser.parse_iso',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.parser.ParserError',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.parser.ParserMatchError',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.parser.TzinfoParser',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.parser.TzinfoParser.parse',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.arrow.parser._Parts',
#  '.home.wsys.ServerlessApp.ServerlessApp-main20220225.testAPP.main.lambda_handler',
#  'arrow',
#  'arrow.__init__',
#  'arrow.__init__.__version__',
#  'arrow.__init__.get',
#  'arrow.__init__.now',
#  'arrow.__version__',
#  'arrow.api',
#  'arrow.api.get',
#  'arrow.api.now',
#  'arrow.arrow',
#  'arrow.arrow.Arrow',
#  'arrow.arrow.Arrow.__init__',
#  'arrow.arrow.Arrow.format',
#  'arrow.arrow.Arrow.fromdate',
#  'arrow.arrow.Arrow.fromdatetime',
#  'arrow.arrow.Arrow.fromtimestamp',
#  'arrow.arrow.Arrow.now',
#  'arrow.arrow.Arrow.utcfromtimestamp',
#  'arrow.arrow.Arrow.utcnow',
#  'arrow.arrow.TZ_EXPR',
#  'arrow.constants',
#  'arrow.constants.DEFAULT_LOCALE',
#  'arrow.constants.MAX_TIMESTAMP',
#  'arrow.constants.MAX_TIMESTAMP_MS',
#  'arrow.constants.MAX_TIMESTAMP_US',
#  'arrow.factory',
#  'arrow.factory.ArrowFactory',
#  'arrow.factory.ArrowFactory.__init__',
#  'arrow.factory.ArrowFactory.get',
#  'arrow.factory.ArrowFactory.now',
#  'arrow.formatter',
#  'arrow.formatter.DateTimeFormatter',
#  'arrow.formatter.DateTimeFormatter.__init__',
#  'arrow.formatter.DateTimeFormatter.format',
#  'arrow.get',
#  'arrow.locales',
#  'arrow.locales.Locale',
#  'arrow.locales.TimeFrameLiteral',
#  'arrow.locales.get_locale',
#  'arrow.now',
#  'arrow.parser',
#  'arrow.parser.DateTimeParser',
#  'arrow.parser.DateTimeParser.__init__',
#  'arrow.parser.DateTimeParser._build_datetime',
#  'arrow.parser.DateTimeParser._generate_pattern_re',
#  'arrow.parser.DateTimeParser._parse_multiformat',
#  'arrow.parser.DateTimeParser._parse_token',
#  'arrow.parser.DateTimeParser.parse',
#  'arrow.parser.DateTimeParser.parse_iso',
#  'arrow.parser.TzinfoParser',
#  'arrow.parser.TzinfoParser.parse',
#  'arrow.util',
#  'arrow.util.is_timestamp',
#  'arrow.util.iso_to_gregorian',
#  'arrow.util.next_weekday',
#  'arrow.util.normalize_timestamp',
#  'calendar',
#  'calendar.timegm',
#  'datetime',
#  'datetime.date',
#  'datetime.date.day',
#  'datetime.date.month',
#  'datetime.date.year',
#  'datetime.datetime',
#  'datetime.datetime.fromtimestamp',
#  'datetime.datetime.max',
#  'datetime.datetime.max.timestamp',
#  'datetime.datetime.max.toordinal',
#  'datetime.datetime.min',
#  'datetime.datetime.now',
#  'datetime.datetime.resolution',
#  'datetime.datetime.strptime',
#  'datetime.datetime.utcfromtimestamp',
#  'datetime.timedelta',
#  'datetime.tzinfo',
#  'dateutil.rrule.WEEKLY',
#  'dateutil.rrule.rrule',
#  'dateutil.tz',
#  'dateutil.tz.gettz',
#  'dateutil.tz.tzlocal',
#  'dateutil.tz.tzoffset',
#  'dateutil.tz.tzutc',
#  'decimal.Decimal',
#  'functools.lru_cache',
#  'logging',
#  'logging.INFO',
#  'logging.getLogger',
#  'main',
#  'main.lambda_handler',
#  're',
#  're.IGNORECASE',
#  're.compile',
#  're.error',
#  're.escape',
#  're.findall',
#  're.split',
#  're.sub',
#  'sys',
#  'sys.maxsize',
#  'sys.version_info',
#  'time',
#  'time.struct_time',
#  'time.time',
#  'typing.Any',
#  'typing.ClassVar',
#  'typing.Dict',
#  'typing.Final',
#  'typing.Iterable',
#  'typing.List',
#  'typing.Literal',
#  'typing.Mapping',
#  'typing.Match',
#  'typing.Optional',
#  'typing.Pattern',
#  'typing.Sequence',
#  'typing.SupportsFloat',
#  'typing.SupportsInt',
#  'typing.Tuple',
#  'typing.Type',
#  'typing.Union',
#  'typing.cast',
#  'typing.overload',
#  'typing_extensions.Final',
#  'typing_extensions.Literal',
#  'unittest.TestCase']

# %% [markdown]
# Generate preloaded package function collections separately
# Library preloaded function collections, passed in by filename

# %%
#(1)------Code implementation to make a copy of the application, delete it after implementation

import shutil
input_package_dynamic_copy = "{}-dynamic".format(input_package)
shutil.copytree(input_package,input_package_dynamic_copy)
# Out:
# 'testAPP-dynamic'

# %%
#(2) Rewrite method to add print
os.system("python3 importprocess.py --path {} ".format(input_package_dynamic_copy))
# Execute the original application, excluding functionality
# Out:
# testAPP-dynamic/main.py
# testAPP-dynamic/arrow/_version.py
# testAPP-dynamic/arrow/constants.py
# testAPP-dynamic/arrow/parser.py
# testAPP-dynamic/arrow/util.py
# testAPP-dynamic/arrow/factory.py
# testAPP-dynamic/arrow/locales.py
# testAPP-dynamic/arrow/api.py
# testAPP-dynamic/arrow/formatter.py
# testAPP-dynamic/arrow/__init__.py
# testAPP-dynamic/arrow/arrow.py
# 0

# %%
#(3) Need to modify the main function file to be executed, to only import the preloaded dependency packages
# Find preloaded functions of related packages, generate, can find related preloading based on available packages. Establish a preloading table
find_package_name = "arrow"
log_name = "log-{}.log".format(find_package_name)
execute_py = "main.py"
os.system("python3 {}/{} >log/{}".format(input_package_dynamic_copy,execute_py,log_name))
# Out:
# 0

# %%
#(4) # This is the preloaded collection generated by the corresponding third-party package, wait until useful functions are generated, then add it to the collection.
log_genrate = "log/{}".format(log_name)
log_handle = "import-prefunc/{}-python36.txt".format(find_package_name)

# %%
import importsort
importsort.sortresult(log_genrate, input_package_dynamic_copy, log_handle)
# Out:
# arrow.arrow.Arrow.__init__
# arrow.arrow.Arrow.fromdatetime
# arrow.factory.ArrowFactory.__init__
# arrow.locales.Locale.__init_subclass__

# %% [markdown]
# step 8

# %%
# Step 8 OK, according to the useful package collection obtained above, add preloaded functions to the final useful function collection

#Final useful function collection
used_fun_result_output_final_re = "used_func_result/used_func_{}_final_re.txt".format(Identify_name)
# Save all preloaded folder directories
prefunc_dir = "import-prefunc"
#Add a library preprocessing collection to the total useful function collection
# python_version = 39
dynamicprocess.result_addlibray(used_fun_result_output_final, used_package_name, prefunc_dir, used_fun_result_output_final_re)
# Out:
# import-prefunc/-python36.txt
# import-prefunc/arrow-python36.txt

# %% [markdown]
# step 9

# %%
dir_name = input_package.split('/')[-1]
used_fun_result_output_final_re = "used_func_result/used_func_reqs_final.txt"

buits_list_file = "built_list.txt"

# %%
import removefile
# removefile.delFiles(input_package, assetsDir)

# %%
gzip_file = "{}/gzipinfo.txt".format(input_package)

# %%
#(1) Function rewriting
os.system("python3 Auto_delete_v6.py --dirname {} --path {} --usedfuntionlist {} --unused_gzip_dir {} --builtlist {}".format(dir_name, input_package, used_fun_result_output_final_re, gzip_file, buits_list_file))
# Out:
# testAPP/main.py
# testAPP/six.py
# code num
# 1
# code num
# 2
# code num
# 1
# code num
# 7
# ............
# ............
# ............
# code num
# 1
# code num
# 1
# code num
# 1
# code num
# 1
# code num
# 1
# code num
# 1
# code num
# 1
# code num
# 1
# code num
# 1
# code num
# 1
# code num
# 1
# code num
# 1
# code num
# 1
# code num
# 1
# code num
# 1
# code num
# 1
# code num
# 1
# code num
# 1
# code num
# 1
# code num
# 1
# code num
# 1
# code num
# 1
# code num
# 1
# code num
# 1
# code num
# 1
# code num
# 9
# ............
# ............
# ............
# code num
# 9
# ............
# ............
# ............
# code num
# 1
# code num
# 48
# ............
# ............
# 1
# ............
# code num
# 5
# ............
# ............
# ............
# code num
# 11
# ............
# ............
# 1
# ............
# code num
# 1
# Decorators(nodes=[<Name.classmethod l.608 at 0x7e972285c4c0>])
# code num
# 18
# ............
# ............
# Decorators(nodes=[<Name.classmethod l.14 at 0x7e9722fb0f40>])
# 1
# ............
# code num
# 15
# ............
# ............
# 1
# ............
# code num
# 5
# ............
# ............
# 1
# ............
# code num
# 9
# ............
# ............
# 1
# ............
# code num
# 6
# ............
# ............
# 1
# ............
# code num
# 6
# ............
# ............
# 1
# ............
# testAPP/custom_funtemplate.py
# code num
# 32
# ............
# ............
# 1
# ............
# testAPP/lazy_import/__init__.py
# code num
# 10
# ............
# ............
# 1
# ............
# code num
# 34
# ............
# ............
# 1
# ............
# code num
# 9
# ............
# ............
# 1
# ............
# code num
# 5
# ............
# ............
# 1
# ............
# code num
# 33
# ............
# ............
# 1
# ............
# code num
# 3
# ............
# ............
# 1
# ............
# code num
# 1
# code num
# 5
# ............
# ............
# ............
# code num
# 4
# ............
# ............
# 1
# ............
# code num
# 12
# ............
# ............
# 1
# ............
# code num
# 11
# ............
# ............
# ............
# code num
# 13
# ............
# ............
# ............
# code num
# 8
# ............
# ............
# ............
# code num
# 5
# ............
# ............
# 1
# ............
# testAPP/arrow/_version.py
# testAPP/arrow/constants.py
# testAPP/arrow/parser.py
# Decorators(nodes=[<Name.overload l.180 at 0x7e9722635df0>])
# Decorators(nodes=[<Name.overload l.184 at 0x7e972263b6d0>])
# Decorators(nodes=[<Name.overload l.188 at 0x7e972263bc10>])
# Decorators(nodes=[<Name.overload l.192 at 0x7e972263f250>])
# Decorators(nodes=[<Name.overload l.196 at 0x7e972263f820>])
# Decorators(nodes=[<Name.staticmethod l.254 at 0x7e97226462e0>])
# Decorators(nodes=[<Name.staticmethod l.339 at 0x7e9722604cd0>])
# Decorators(nodes=[<Name.classmethod l.348 at 0x7e972260a7f0>])
# testAPP/arrow/util.py
# code num
# 2
# code num
# 2
# testAPP/arrow/factory.py
# Decorators(nodes=[<Name.overload l.33 at 0x7e9722731550>])
# Decorators(nodes=[<Name.overload l.37 at 0x7e97226c28b0>])
# Decorators(nodes=[<Name.overload l.41 at 0x7e97226c2880>])
# Decorators(nodes=[<Name.overload l.45 at 0x7e97226d88b0>])
# testAPP/arrow/locales.py
# code num
# 2
# testAPP/arrow/api.py
# Decorators(nodes=[<Name.overload l.16 at 0x7e97228c7d90>])
# Decorators(nodes=[<Name.overload l.20 at 0x7e9722703e20>])
# Decorators(nodes=[<Name.overload l.24 at 0x7e97227039d0>])
# Decorators(nodes=[<Name.overload l.28 at 0x7e972270c370>])
# Decorators(nodes=[<Name.overload l.32 at 0x7e97228ccb80>])
# code num
# 1
# code num
# 1
# testAPP/arrow/formatter.py
# testAPP/arrow/__init__.py
# testAPP/arrow/arrow.py
# Decorators(nodes=[<Name.classmethod l.91 at 0x7e9722267910>])
# Decorators(nodes=[<Name.classmethod l.109 at 0x7e972226df40>])
# Decorators(nodes=[<Name.classmethod l.123 at 0x7e97228d9970>])
# Decorators(nodes=[<Name.classmethod l.142 at 0x7e97228d9a90>])
# Decorators(nodes=[<Name.classmethod l.155 at 0x7e97223e8fd0>])
# Decorators(nodes=[<Name.classmethod l.179 at 0x7e97225ac6d0>])
# Decorators(nodes=[<Name.classmethod l.192 at 0x7e97225ace50>])
# Decorators(nodes=[<Name.classmethod l.213 at 0x7e97222708e0>])
# Decorators(nodes=[<Name.classmethod l.230 at 0x7e9722424c40>])
# Decorators(nodes=[<Name.classmethod l.404 at 0x7e972233d5b0>])
# Decorators(nodes=[<Name.classmethod l.475 at 0x7e97223469a0>])
# Decorators(nodes=[<Name.property l.558 at 0x7e9722467400>])
# property
# Decorators(nodes=[<Name.property l.571 at 0x7e9722467700>])
# property
# Decorators(nodes=[<Name.property l.584 at 0x7e9722467880>])
# property
# Decorators(nodes=[<Name.property l.612 at 0x7e9722467c40>])
# property
# Decorators(nodes=[<Name.property l.625 at 0x7e9722467df0>])
# property
# Decorators(nodes=[<Name.property l.638 at 0x7e972246f070>])
# property
# Decorators(nodes=[<Name.property l.643 at 0x7e972246f250>])
# property
# Decorators(nodes=[<Name.property l.651 at 0x7e972246f460>])
# property
# Decorators(nodes=[<Name.overload l.1246 at 0x7e972254c070>])
# Decorators(nodes=[<Name.overload l.1250 at 0x7e972254c3a0>])
# Decorators(nodes=[<Name.staticmethod l.1298 at 0x7e9722530f10>])
# Decorators(nodes=[<Name.classmethod l.1311 at 0x7e9722530bb0>])
# Decorators(nodes=[<Name.classmethod l.1324 at 0x7e9722530430>])
# Decorators(nodes=[<Name.classmethod l.1343 at 0x7e97225276a0>])
# Decorators(nodes=[<Name.staticmethod l.1355 at 0x7e972251e4f0>])
# 0

# %%
# (2) Copy customized file custom_funtemplate
import shutil
shutil.copy("custom_funtemplate_final_clear.py", "{}/custom_funtemplate.py".format(input_package))
# Out:
# 'testAPP/custom_funtemplate.py'

# %% [markdown]
# step 10

# %%
input_package_copy = input_package
dir_name = input_package_copy.split('/')[-1]

import removefile
removefile.delFiles(input_package_copy, assetsDir)

# %%
#(1) To accurately rewrite import statements, find out what the module collection has
module_name = "module_file/module_name_{}.txt".format(Identify_name)
utiltool.get_module(input_package_copy, module_name)

# %%
# (2) Rewrite import again, note that the rewritten import uses lazy import method
os.system("python3 Auto_delete_vtestimportv3.py --dirname {} --path {} --usedfuntionlist {} --builtlist {} --module_name {}".format(dir_name, input_package_copy, used_fun_result_output_final_re, buits_list_file, module_name))
# Out:
# testAPP/main.py
# testAPP/six.py
# rewrite：itertools = lazy_import.lazy_callable('itertools')
# rewrite：operator = lazy_import.lazy_callable('operator')
# rewrite：types = lazy_import.lazy_callable('types')
# testAPP/custom_funtemplate.py
# rewrite：os = lazy_import.lazy_callable('os')
# rewrite：json = lazy_import.lazy_callable('json')
# testAPP/lazy_import/__init__.py
# rewrite：raise_from = lazy_import.lazy_callable('six.raise_from')
# testAPP/arrow/_version.py
# testAPP/arrow/constants.py
# testAPP/arrow/parser.py
# testAPP/arrow/util.py
# testAPP/arrow/factory.py
# testAPP/arrow/locales.py
# testAPP/arrow/api.py
# testAPP/arrow/formatter.py
# testAPP/arrow/__init__.py
# testAPP/arrow/arrow.py
# 0

# %%
# After rewriting, need to put our modified lazy_import package and learned six.py file in for execution.
#(3) Import lazy import, as well as the dependent six.py file
shutil.copytree("lazy_import","{}/lazy_import".format(input_package_copy))
shutil.copy("six.py", "{}/six.py".format(input_package_copy))
